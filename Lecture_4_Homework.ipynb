# %% [markdown]
# # NETID: EJL242

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Import the data. Make sure that lecture4data.csv is in the same folder as this file!
original_data = pd.read_csv('lecture4data.csv')

# %% [markdown]
# # Problem  1: Python Practice

# %%
p1data = original_data.copy()

# %% [markdown]
# ### a) Print out the first few rows of `problem_1_data`

# %%
p1data[['name','city','state']]
# Out:
#                                                 name             city state
# 0                           Alabama A & M University           Normal    AL
# 1                University of Alabama at Birmingham       Birmingham    AL
# 2                University of Alabama in Huntsville       Huntsville    AL
# 3                           Alabama State University       Montgomery    AL
# 4                          The University of Alabama       Tuscaloosa    AL
# 5                    Auburn University at Montgomery       Montgomery    AL
# 6                                  Auburn University           Auburn    AL
# 7                        Birmingham Southern College       Birmingham    AL
# 8                          Concordia College Alabama            Selma    AL
# 9                                Faulkner University       Montgomery    AL
# 10                     Herzing University-Birmingham       Birmingham    AL
# 11                                Huntingdon College       Montgomery    AL
# 12                     Jacksonville State University     Jacksonville    AL
# 13                                    Judson College           Marion    AL
# 14                        University of West Alabama       Livingston    AL
# 15                              University of Mobile           Mobile    AL
# 16                          University of Montevallo       Montevallo    AL
# 17                       University of North Alabama         Florence    AL
# 18                                Oakwood University       Huntsville    AL
# 19                                Samford University       Birmingham    AL
# 20                       University of South Alabama           Mobile    AL
# 21                               Spring Hill College           Mobile    AL
# 22                        Southeastern Bible College       Birmingham    AL
# 23                                  Stillman College       Tuscaloosa    AL
# 24                                   Troy University             Troy    AL
# 25                               Tuskegee University         Tuskegee    AL
# 26                    University of Alaska Anchorage        Anchorage    AK
# 27                    University of Alaska Fairbanks        Fairbanks    AK
# 28                    University of Alaska Southeast           Juneau    AK
# 29                         Alaska Pacific University        Anchorage    AK
# ...                                              ...              ...   ...
# 1554        California State University-Monterey Bay          Seaside    CA
# 1555                  ITT Technical Institute-Oxnard           Oxnard    CA
# 1556                 ITT Technical Institute-Everett          Everett    WA
# 1557             ITT Technical Institute-Orland Park      Orland Park    IL
# 1558          Johnson & Wales University-North Miami      North Miami    FL
# 1559                               Messenger College           Euless    TX
# 1560          New York College of Health Professions          Syosset    NY
# 1561            Arizona State University-Polytechnic             Mesa    AZ
# 1562  Embry-Riddle Aeronautical University-Worldwide    Daytona Beach    FL
# 1563                 ITT Technical Institute-Hialeah          Hialeah    FL
# 1564                       Herzing University-Kenner           Kenner    LA
# 1565                   Florida Gulf Coast University       Fort Myers    FL
# 1566                       Michigan Jewish Institute     W Bloomfield    MI
# 1567               ITT Technical Institute-Oak Brook        Oak Brook    IL
# 1568            University of Connecticut-Tri-Campus        Waterbury    CT
# 1569           University of Connecticut-Avery Point           Groton    CT
# 1570              University of Connecticut-Stamford         Stamford    CT
# 1571                ITT Technical Institute-Richmond         Richmond    VA
# 1572                 ITT Technical Institute-Lathrop          Lathrop    CA
# 1573              ITT Technical Institute-Wilmington       Wilmington    MA
# 1574               Johnson & Wales University-Denver           Denver    CO
# 1575                           The King's University        Southlake    TX
# 1576     California State University-Channel Islands        Camarillo    CA
# 1577                  ITT Technical Institute-Canton           Canton    MI
# 1578               West Coast University-Los Angeles  North Hollywood    CA
# 1579                 DigiPen Institute of Technology          Redmond    WA
# 1580          National University College-Rio Grande       Rio Grande    PR
# 1581                              Neumont University   Salt Lake City    UT
# 1582            Johnson & Wales University-Charlotte        Charlotte    NC
# 1583                ITT Technical Institute-Kennesaw         Kennesaw    GA
#
# [1584 rows x 3 columns]

# %% [markdown]
# ### b) Add a new column to `problem_1_data` called `education_profit_ratio` that holds each schools' `median_earnings` divided by its `cost`.

# %%
def f(x,y):
    return x/y
p1data['education_profit_ratio'] = p1data.apply(lambda x: f(x.median_earnings, x.cost), axis=1)
p1data[['median_earnings','cost','education_profit_ratio']]
# Out:
#       median_earnings   cost  education_profit_ratio
# 0               29900  20809                1.436878
# 1               40200  22232                1.808204
# 2               45600  20999                2.171532
# 3               26700  18100                1.475138
# 4               42700  27205                1.569564
# 5               33500  18665                1.794803
# 6               47100  29164                1.615005
# 7               45600  46730                0.975819
# 8               20600  27036                0.761947
# 9               35900  30539                1.175546
# 10              40300  26546                1.518119
# 11              36800  33434                1.100676
# 12              35000  20030                1.747379
# 13              27800  29742                0.934705
# 14              36200  17848                2.028238
# 15              35000  32349                1.081950
# 16              33100  22840                1.449212
# 17              36400  16135                2.255965
# 18              32200  35546                0.905868
# 19              46300  42270                1.095339
# 20              37000  19654                1.882568
# 21              42400  45489                0.932093
# 22              31600  18988                1.664209
# 23              27200  26466                1.027734
# 24              35800  17898                2.000223
# 25              35300  34354                1.027537
# 26              43300  14476                2.991158
# 27              37100  16025                2.315133
# 28              36800  18474                1.991989
# 29              39000  31435                1.240655
# ...               ...    ...                     ...
# 1554            42200  19375                2.178065
# 1555            38800  28106                1.380488
# 1556            39500  27301                1.446833
# 1557            38800  27987                1.386358
# 1558            36600  41154                0.889342
# 1559            18800  21009                0.894855
# 1560            29300  22898                1.279588
# 1561            45400  22762                1.994552
# 1562            62400  21900                2.849315
# 1563            38800  28921                1.341586
# 1564            40300  26781                1.504798
# 1565            41000  18691                2.193569
# 1566            21900  17979                1.218088
# 1567            38800  27165                1.428308
# 1568            55800  14647                3.809654
# 1569            55800  14538                3.838217
# 1570            55800  14303                3.901279
# 1571            38800  27983                1.386556
# 1572            38800  26763                1.449763
# 1573            38800  26943                1.440077
# 1574            36600  41127                0.889926
# 1575            35300  24109                1.464183
# 1576            45500  22292                2.041091
# 1577            38800  28525                1.360210
# 1578            46400  46040                1.007819
# 1579            81300  41573                1.955596
# 1580            17100  13739                1.244632
# 1581            47900  31821                1.505295
# 1582            36600  42124                0.868863
# 1583            38800  27339                1.419218
#
# [1584 rows x 3 columns]

# %% [markdown]
# ### c) (OPTIONAL) Briefly describe what `cost_single_brackets`, `cost_double_brackets`, and `multiple_columns` look like (what their shapes/dimensions are).
#
# <b>Hint</b>: You can use Python's `type` function to tell the type of an objective. For example, `print(type(dylanIsCool))` will print out the type of `dylanIsCool`. You can also try printing out the object to see what it looks like.

# %%
multiple_columns = p1data[['cost', 'median_earnings']]
cost_single_brackets = p1data['cost']
cost_double_brackets = p1data[['cost']]

# %%
print(type(cost_single_brackets))
print(type(cost_double_brackets))
print(type(multiple_columns))

print()
print("cost_single_brackets")
print(cost_single_brackets)

print()
print("cost_double_brackets")
print(cost_double_brackets)

print()
print("multiple_columns")
print(multiple_columns)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
#
# cost_single_brackets
# 0       20809
# 1       22232
# 2       20999
# 3       18100
# 4       27205
# 5       18665
# 6       29164
# 7       46730
# 8       27036
# 9       30539
# 10      26546
# 11      33434
# 12      20030
# 13      29742
# 14      17848
# 15      32349
# 16      22840
# 17      16135
# 18      35546
# 19      42270
# 20      19654
# 21      45489
# 22      18988
# 23      26466
# 24      17898
# 25      34354
# 26      14476
# 27      16025
# 28      18474
# 29      31435
#         ...
# 1554    19375
# 1555    28106
# 1556    27301
# 1557    27987
# 1558    41154
# 1559    21009
# 1560    22898
# 1561    22762
# 1562    21900
# 1563    28921
# 1564    26781
# 1565    18691
# 1566    17979
# 1567    27165
# 1568    14647
# 1569    14538
# 1570    14303
# 1571    27983
# 1572    26763
# 1573    26943
# 1574    41127
# 1575    24109
# 1576    22292
# 1577    28525
# 1578    46040
# 1579    41573
# 1580    13739
# 1581    31821
# 1582    42124
# 1583    27339
# Name: cost, Length: 1584, dtype: int64
#
# cost_double_brackets
#        cost
# 0     20809
# 1     22232
# 2     20999
# 3     18100
# 4     27205
# 5     18665
# 6     29164
# 7     46730
# 8     27036
# 9     30539
# 10    26546
# 11    33434
# 12    20030
# 13    29742
# 14    17848
# 15    32349
# 16    22840
# 17    16135
# 18    35546
# 19    42270
# 20    19654
# 21    45489
# 22    18988
# 23    26466
# 24    17898
# 25    34354
# 26    14476
# 27    16025
# 28    18474
# 29    31435
# ...     ...
# 1554  19375
# 1555  28106
# 1556  27301
# 1557  27987
# 1558  41154
# 1559  21009
# 1560  22898
# 1561  22762
# 1562  21900
# 1563  28921
# 1564  26781
# 1565  18691
# 1566  17979
# 1567  27165
# 1568  14647
# 1569  14538
# 1570  14303
# 1571  27983
# 1572  26763
# 1573  26943
# 1574  41127
# 1575  24109
# 1576  22292
# 1577  28525
# 1578  46040
# 1579  41573
# 1580  13739
# 1581  31821
# 1582  42124
# 1583  27339
#
# [1584 rows x 1 columns]
#
# multiple_columns
#        cost  median_earnings
# 0     20809            29900
# 1     22232            40200
# 2     20999            45600
# 3     18100            26700
# 4     27205            42700
# 5     18665            33500
# 6     29164            47100
# 7     46730            45600
# 8     27036            20600
# 9     30539            35900
# 10    26546            40300
# 11    33434            36800
# 12    20030            35000
# 13    29742            27800
# 14    17848            36200
# 15    32349            35000
# 16    22840            33100
# 17    16135            36400
# 18    35546            32200
# 19    42270            46300
# 20    19654            37000
# 21    45489            42400
# 22    18988            31600
# 23    26466            27200
# 24    17898            35800
# 25    34354            35300
# 26    14476            43300
# 27    16025            37100
# 28    18474            36800
# 29    31435            39000
# ...     ...              ...
# 1554  19375            42200
# 1555  28106            38800
# 1556  27301            39500
# 1557  27987            38800
# 1558  41154            36600
# 1559  21009            18800
# 1560  22898            29300
# 1561  22762            45400
# 1562  21900            62400
# 1563  28921            38800
# 1564  26781            40300
# 1565  18691            41000
# 1566  17979            21900
# 1567  27165            38800
# 1568  14647            55800
# 1569  14538            55800
# 1570  14303            55800
# 1571  27983            38800
# 1572  26763            38800
# 1573  26943            38800
# 1574  41127            36600
# 1575  24109            35300
# 1576  22292            45500
# 1577  28525            38800
# 1578  46040            46400
# 1579  41573            81300
# 1580  13739            17100
# 1581  31821            47900
# 1582  42124            36600
# 1583  27339            38800
#
# [1584 rows x 2 columns]

# %% [markdown]
# cost_single_brackets is a series with a bunch of int64 values
#
# cost_double_brackets is a dataframe object, but only has one column of data, so it appears the same as cost_single_brackets, but has different methods and properties because it is a dataframe object compared to a series
#
# multiple_columns is also a dataframe object like cost_double_brackets, but as the name suggests, it has multiple columns of data

# %% [markdown]
# # Basics of Machine Learning
#
# So far we have discussed the importance of data visualization and data preprocessing. These steps are important in preparing the datasets. Now, we will start our machine learning section of the course. We have already discussed how a machine learning model is like a function, and we will now explain a bit more using __linear regression__ models. Before we begin, we should import some useful python.

# %% [markdown]
# This dataset contains information on different colleges across the US. The full dataset was assembled from https://collegescorecard.ed.gov/data/ and this version was trimmed down to a few important columns and cleaned to removed schools with missing data.
#
# We will look at adm_rate (admission rate), undergrads (number of undergrads), cost (cost to attand the college for a year), compl_4 (percent of students graduated in 4 years), median_hh_inc (median household income of students), and median_earnings (median earnings 10 years after starting college).
#
# We want to predict median_earnings using other columns in the data set. In other words, we have some inputs from the dataframe (such as cost), and we want to output another column in the dataframe (median_earnings).

# %% [markdown]
# # Section 1: Intro

# %% [markdown]
# To keep things clean throughout this Jupyter Notebook, in each section, we first make a copy of the original data. You won't have to do this in your own projects.

# %%
section_1_data = original_data.copy()
section_1_data.head()
# Out:
#                                   name        city state  adm_rate  \
# 0             Alabama A & M University      Normal    AL    0.6538
# 1  University of Alabama at Birmingham  Birmingham    AL    0.6043
# 2  University of Alabama in Huntsville  Huntsville    AL    0.8120
# 3             Alabama State University  Montgomery    AL    0.4639
# 4            The University of Alabama  Tuscaloosa    AL    0.5359
#
#    undergrads   cost  compl_4  median_hh_inc  median_earnings
# 0        4505  20809   0.1104       49720.22            29900
# 1       11269  22232   0.3173       55735.22            40200
# 2        5829  20999   0.1848       58688.62            45600
# 3        4740  18100   0.1216       46065.20            26700
# 4       31005  27205   0.4135       57928.41            42700

# %% [markdown]
# Now, let's start machine learning! We'll choose a set of inputs, and then use machine learning to predict median_earnings using that set of inputs

# %%
inputs = section_1_data[['cost']]
outputs = section_1_data['median_earnings']

# %%
print(type(inputs))
inputs.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     cost
# 0  20809
# 1  22232
# 2  20999
# 3  18100
# 4  27205

# %%
print(type(outputs))
outputs[:5]
# Out:
# <class 'pandas.core.series.Series'>
# 0    29900
# 1    40200
# 2    45600
# 3    26700
# 4    42700
# Name: median_earnings, dtype: int64

# %%
ML_object_that_predicts = LinearRegression()

# %% [markdown]
# We called a function in sklearn called `LinearRegression` and stored the result in `ML_object_that_predicts`. `ML_object_that_predicts` is an object with several useful functions. You can access these functions through `ML_object_that_predicts.<insert function name here>`. As its name implies, we'll use these functions to make predictions.
#
# To do this, we're use the `fit` function and `predict` functions. We'll go into what fitting is later. To predict, give `ML_object_that_predicts` a set of inputs, and it'll spit out a set of predictions based on those inputs.

# %%
known_input, future_input, known_output, future_output = train_test_split(inputs, outputs, test_size=0.2, random_state=42)

ML_object_that_predicts.fit(known_input, known_output) # tell it known stuff

predictions = ML_object_that_predicts.predict(future_input) # given future input, predict future output!

# compare actual median_earnings and the predicted median_earnings
pd.DataFrame({"REAL median_income":future_output, "PREDICTED median_income":predictions}).reset_index(drop=True).head(10)
# Out:
#    REAL median_income  PREDICTED median_income
# 0               36200             35659.150942
# 1               42700             44239.451395
# 2               42500             37177.409277
# 3               42800             42462.534625
# 4               35200             45324.623556
# 5               45800             41478.088340
# 6               49200             48904.428228
# 7               31100             44439.499303
# 8               43900             36473.381025
# 9               21400             42818.760286

# %% [markdown]
# Now we'll call the `score` function of `ML_object_that_predicts`. This returns a "score", which is a measure of how accurate the predictions are. The best score is 1, and negative scores are really bad.

# %%
print("Score:", ML_object_that_predicts.score(future_input, future_output))
# Out:
# Score: 0.17036266107284004

# %% [markdown]
# Let's quickly visualize what we just did. The blue points are the true values, and the black points (which are close together, so they look like a line) are our predictions. Our predictions aren't super accurate, but they're somewhat close for most points.

# %%
plt.scatter(future_input, future_output)
plt.plot(future_input, predictions, 'k', linewidth=4)
plt.legend(["Predictions","Actual Values"])
plt.title('Cost of Attendance vs Median Earnings')
plt.xlabel('Cost of Attendance')
plt.ylabel('Median Earnings')
plt.show()

# %% [markdown]
# ### Summary:
#
# sklearn has a function called `ML_object_that_predicts`. We "fit" it on some inputs and outputs. Then, we give `ML_object_that_predicts` some more inputs, and it predicts outputs.
#
# ### What we don't know:
#
# What's "fitting"?
#
# Why do we split the dataset up?
#
# How does the model make predictions?
#
# How do we increase the model's score (how do we make our model better)?

# %% [markdown]
# # Section 2: Fitting / Training

# %%
section_2_data = original_data.copy()

# %% [markdown]
# The inputs are called "features", and the output is called the "target".
#
# `ML_object_that_predicts` is a "model"

# %%
features = section_2_data[['cost']]
target = section_2_data['median_earnings']
model = LinearRegression()

# %% [markdown]
# In reality, we will train a model on known data, and that model is our product -- we're done with it, and we ship it out to be used. The user will give it new data, and the model will predict the corresponding outputs.
# We emulate that by splitting our data into "known" data and "new" data. There're a lot of synonyms for known data and new data, and we'll introduce a couple today.

# %%
from sklearn.model_selection import train_test_split
known_data, new_data, known_output, goal_output = train_test_split(features, target, test_size=0.2, random_state=42)

# Here, we call the values we are trying to predict the "goal_output".
# Our goal is to make a model that, when given known_output, can try to predict goal_output.

model.fit(known_data, known_output) # train/fit on known inputs
predictions = model.predict(new_data) # predict on new data

print("Score:", model.score(new_data, goal_output))
# Out:
# Score: 0.19556440347189818

# %% [markdown]
# ### Summary
# `LinearRegression()` returns a "model", which is an object that we first train, then use to predict values. To train, we call `model.fit` with known features and their corresponding outputs. To predict, we call `model.predict` on some new set of data, which it wasn't trained on
#
# ### What we still don't know
#
# How does the model make predictions?
#
# How do we increase the model's score (how do we make our model better)?

# %% [markdown]
# # Section 3: Models

# %%
section_3_data = original_data.copy()

# %%
features = section_3_data[['cost','adm_rate']]
target = section_3_data['median_earnings']
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Running the following cell will pull up a description of `model`.

# %%
# if the popup annoys you, then feel free to comment out the following line
model?
# Out:
# Object `model` not found.

# %%
model.coef_
# Out:
# array([0.35096124])

# %%
model.intercept_
# Out:
# 29969.36728170921

# %% [markdown]
# `model` is a linear regression model of the form $y = B_1*x_1 + B_2*x_2 + k$, where:
#
# $y = $ median_earnings, our target
#
# $x_1 = $ cost
#
# $B_1 = 3.14511519e-01$, the coefficient on cost
#
# $x_2 = $ admission rate
#
# $B_2 = -8.76543392e+03$, the coefficient on admission rate
#
# $k = 37049.972$, the intercept.
#
# We won't talk too much about the intercept in this class, but if you're interested in learning more, feel free to ask us after class.
#
# Say you have information about a school's cost and admission rate. Then, `model` can use the school's cost and admission rate to predict the school's median earnings. How does it do that? It calculates $predicted\_median\_earnings = B_1*cost + B_2 * x_2$
#
# Let's try this out on an example.

# %%
section_3_data.loc[1:1]
# Out:
#                                   name        city state  adm_rate  \
# 1  University of Alabama at Birmingham  Birmingham    AL    0.6043
#
#    undergrads   cost  compl_4  median_hh_inc  median_earnings
# 1       11269  22232   0.3173       55735.22            40200

# %%
example_cost = 22232
example_admission_rate = 0.6043

# %%
B1 = model.coef_[0]
B2 = model.coef_[1]
k = model.intercept_
manually_predicted_median_earnings = B1 * example_cost + B2 * example_admission_rate + k
print(manually_predicted_median_earnings)
# Out:
# 38745.240382799544

# %%
model.predict([[example_cost,example_admission_rate]])[0]
# Out:
# 38745.240382799544

# %% [markdown]
# The two results were the same. From this, we can conclude that `model.predict` is really just outputting $B_1*x_1 + B_2*x_2 + k$.
#
# (When we look at other algorithms in later lectures, the equation will be different. However, the general idea is the same: `model.fit` created an equation, and `model.predict` uses that equation)

# %% [markdown]
# ### Summary
# Our `model` is an object. When we train it (by calling `model.fit`), we're setting its parameters (for example, $B_1$, $B_2$, and k). When we predict (by calling `model.predict(new_data)`), `model` is applying a function to each row of `new_data` in order to get a prediction.
#
#
# ### What we still don't know
#
# How do we increase the model's score (how do we make our model better)?

# %% [markdown]
# ## Problem 2
#
# Use 'cost' and 'compl_4' to predict 'median_earnings'.
#
# Use a train test split of 25% as a test set (not 20%, which all the previous examples used).
#
# Print out the median_earnings predicted for the test set. Also print out the model's score.

# %%
problem_2_data = original_data.copy()

# %%
# Fill in this cell with your code. We've provided helpful psuedocode.
# define X = the cost and compl_4 columns
# define Y = median_earnings

X = problem_2_data[['cost','compl_4']]
Y = problem_2_data[['median_earnings']]

# split X and Y into train and test sets (using sklearn)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# create your model
model = LinearRegression()

# fit your model
model.fit(x_train, y_train)

# predict and print out the median earnings for the test set
print(model.predict(x_test))

# print out the score
print("Score:", model.score(x_test, y_test))
# Out:
# [[34997.04553837]
#  [40256.77765219]
#  [36515.00222188]
#  [40065.94056499]
#  [44154.6934188 ]
#  [37254.56657716]
#  [50543.4358826 ]
#  [45179.32647619]
#  [36408.60305709]
#  [36817.82228584]
#  [40065.94056499]
#  [37056.95204229]
#  [53946.90604725]
#  [49254.41848669]
#  [51712.07655223]
#  [49032.21209898]
#  [46908.8813621 ]
#  [51634.6341556 ]
#  [42300.47942943]
#  [41813.84612823]
#  [33581.06087747]
#  [33071.38024374]
#  [46654.57772052]
#  [39656.77944005]
#  [36086.95923921]
#  [37797.68826651]
#  [39504.54887513]
#  [50183.53777102]
#  [51630.8031542 ]
#  [50461.5567993 ]
#  [54411.09032731]
#  [40428.69902454]
#  [36143.17724212]
#  [47107.54551819]
#  [39939.12843613]
#  [37732.33921404]
#  [40963.5059981 ]
#  [43360.91288529]
#  [43085.24326991]
#  [35360.96836111]
#  [45711.53688403]
#  [43862.25735599]
#  [32174.20452243]
#  [46505.84916083]
#  [46096.52850278]
#  [39766.37228004]
#  [52078.68038569]
#  [37814.02579968]
#  [34656.84224576]
#  [48040.35509604]
#  [46632.79492283]
#  [45060.08642795]
#  [35833.58470056]
#  [35374.3216453 ]
#  [39245.62673988]
#  [35006.59729147]
#  [41012.98677008]
#  [45827.96939854]
#  [45173.66420357]
#  [44056.14779597]
#  [41904.00741416]
#  [35627.82155062]
#  [53786.50267633]
#  [41239.5093921 ]
#  [45376.9463462 ]
#  [32709.89821157]
#  [41402.99545423]
#  [44075.45850202]
#  [41752.60859016]
#  [35321.40582164]
#  [33303.89560023]
#  [37430.96626282]
#  [41426.38591206]
#  [48918.63604259]
#  [35236.21354893]
#  [43046.15227542]
#  [46268.93332286]
#  [43151.91449945]
#  [44610.99112644]
#  [37187.50849101]
#  [46536.34600675]
#  [43501.17260734]
#  [36769.80744165]
#  [38435.65904727]
#  [49014.32329026]
#  [46034.57078087]
#  [35449.36550681]
#  [42537.84702864]
#  [35891.13125034]
#  [54851.92010117]
#  [35657.31885605]
#  [45383.94594948]
#  [35444.2953736 ]
#  [47959.08024253]
#  [45844.05002639]
#  [35258.3890557 ]
#  [34510.10150333]
#  [52351.51912342]
#  [33746.54939311]
#  [34153.83374053]
#  [37648.44736185]
#  [43367.78247133]
#  [45552.56253075]
#  [45140.31242094]
#  [37303.38432077]
#  [38932.21612412]
#  [55313.18606133]
#  [46715.92631871]
#  [44492.90633809]
#  [47180.23303412]
#  [48447.20359652]
#  [48530.76384072]
#  [37191.88708405]
#  [50008.60516949]
#  [53680.85423574]
#  [39960.08855064]
#  [40726.58124446]
#  [43142.32004968]
#  [36980.74617584]
#  [39661.23185338]
#  [34957.00095089]
#  [47668.55009786]
#  [41707.67223801]
#  [33436.77479097]
#  [46498.88736028]
#  [40891.04871662]
#  [47612.6965458 ]
#  [39195.62267871]
#  [38533.2183002 ]
#  [36256.65160545]
#  [53413.1693155 ]
#  [52967.86549345]
#  [37122.96145556]
#  [47303.55487287]
#  [43507.60113299]
#  [51076.09638818]
#  [36547.07471173]
#  [42573.95294749]
#  [35549.62283091]
#  [34303.6268874 ]
#  [41674.81084598]
#  [40913.08829794]
#  [37866.20885218]
#  [42624.84875006]
#  [43190.82979296]
#  [42404.45066491]
#  [49556.1996099 ]
#  [41968.14839251]
#  [39796.64741154]
#  [41966.68156195]
#  [45152.93669193]
#  [46646.31805553]
#  [39583.46586164]
#  [42902.00135367]
#  [52728.45566521]
#  [46195.35285344]
#  [51510.44622187]
#  [46560.15666099]
#  [41042.48827468]
#  [34296.47984138]
#  [49429.64929048]
#  [38539.03374634]
#  [51568.46055866]
#  [35450.96794331]
#  [48012.9249713 ]
#  [53091.76400871]
#  [35037.55244585]
#  [36753.10527   ]
#  [43699.8409626 ]
#  [32984.24234329]
#  [41736.64606661]
#  [41734.50907718]
#  [55485.07026997]
#  [33085.48819772]
#  [36440.12712866]
#  [46640.75741003]
#  [36903.60287406]
#  [49348.53422366]
#  [36141.30027698]
#  [32802.14067543]
#  [46871.61496991]
#  [49081.47390024]
#  [40238.58192336]
#  [41696.84247016]
#  [49856.06387074]
#  [46844.06539689]
#  [44769.25718843]
#  [44433.958258  ]
#  [35080.25788503]
#  [39643.79957813]
#  [33376.85695004]
#  [36613.77114648]
#  [38308.00164184]
#  [44866.00150733]
#  [45614.35365499]
#  [41059.79079645]
#  [36851.53621682]
#  [45672.61599162]
#  [47850.52697213]
#  [55573.5558722 ]
#  [52152.61124278]
#  [38499.99055047]
#  [40696.26589623]
#  [51758.46795389]
#  [40571.06798492]
#  [46935.8277196 ]
#  [34330.24545062]
#  [35824.09646253]
#  [45526.06698614]
#  [44080.85349818]
#  [35740.3610245 ]
#  [54595.04954163]
#  [36216.56902761]
#  [33590.34287417]
#  [34964.40795524]
#  [38109.05722632]
#  [39864.70026594]
#  [49623.17903758]
#  [37124.59685659]
#  [36789.34342227]
#  [44929.04283947]
#  [41526.68854463]
#  [35905.33720535]
#  [47011.96123144]
#  [50325.36327299]
#  [41527.41922131]
#  [35992.9697615 ]
#  [39909.97522471]
#  [51429.6975787 ]
#  [51300.53808586]
#  [37556.56158951]
#  [35227.36739917]
#  [44778.11562639]
#  [40541.01882275]
#  [38326.43428422]
#  [53845.75436994]
#  [37123.42937445]
#  [42331.15757522]
#  [38702.48417637]
#  [55499.5026457 ]
#  [35367.48151939]
#  [55731.49879047]
#  [34846.14326675]
#  [41036.23710328]
#  [35156.2865189 ]
#  [43541.20230499]
#  [56202.33788504]
#  [44843.60518892]
#  [40347.62022884]
#  [38677.42382137]
#  [43958.31745285]
#  [40047.95483545]
#  [42806.3101604 ]
#  [41826.56139144]
#  [41497.54417275]
#  [31144.31315504]
#  [46393.32044355]
#  [38480.13460083]
#  [52367.58180843]
#  [46204.64095617]
#  [44301.63073637]
#  [42607.8211322 ]
#  [34600.24840658]
#  [54388.04019534]
#  [35646.66000674]
#  [48988.11639322]
#  [39315.88734078]
#  [55696.54457135]
#  [36485.54278512]
#  [37374.80043512]
#  [42051.98996616]
#  [41350.912122  ]
#  [42548.32068823]
#  [35609.50045511]
#  [36206.46732462]
#  [34128.2606653 ]
#  [39234.67249795]
#  [36917.68212861]
#  [45771.8807079 ]
#  [46917.83136535]
#  [45949.52767013]
#  [38336.65995416]
#  [34972.88093631]
#  [36127.07478158]
#  [39042.91719628]
#  [39145.32926501]
#  [56250.62095403]
#  [42798.64720925]
#  [40966.39516719]
#  [54709.56743034]
#  [37906.98824957]
#  [37924.48174758]
#  [38410.51329894]
#  [34667.06383822]
#  [35927.24015627]
#  [44686.353613  ]
#  [39950.21816231]
#  [37718.46887857]
#  [45607.22500319]
#  [34012.75329792]
#  [41953.07124056]
#  [36727.89543352]
#  [40850.86832538]
#  [35084.61611104]
#  [36112.6317152 ]
#  [39882.20750763]
#  [35325.75883421]
#  [36506.88681473]
#  [37515.19220295]
#  [51574.79254895]
#  [36743.11677738]
#  [35985.85045638]
#  [38932.21612412]
#  [37530.37720974]
#  [42953.98700437]
#  [40693.68294229]
#  [44528.97096001]
#  [39558.82392808]
#  [43178.50487039]
#  [44381.16550871]
#  [45829.93316692]
#  [39756.61867241]
#  [41467.99411903]
#  [39636.82466274]
#  [34517.39803083]
#  [34006.02269034]
#  [35889.89173308]
#  [37791.72467267]
#  [53104.38159041]
#  [39786.38789467]
#  [44471.6666793 ]
#  [35726.62050844]
#  [37562.30021811]
#  [43217.04018421]
#  [35524.33860106]
#  [44392.53784238]
#  [31818.25017123]
#  [41467.46650897]
#  [44483.36318115]
#  [38192.49134314]
#  [48401.14189601]
#  [41460.46901038]
#  [35341.09777522]
#  [50070.8343011 ]
#  [41380.52466634]
#  [39632.74293817]
#  [49769.52866848]
#  [55458.38635074]
#  [39624.90371297]
#  [39333.70163446]
#  [37456.76212249]
#  [34643.01645806]
#  [38903.04006574]
#  [45480.85566414]
#  [34386.97057488]
#  [43294.87140007]
#  [44744.91001866]
#  [41467.46650897]
#  [42548.92441088]
#  [46861.75304586]
#  [51604.87378308]
#  [33991.29529724]
#  [40910.88239236]
#  [37879.37167745]
#  [35889.95784979]
#  [39502.77449564]
#  [46935.88231901]
#  [43025.91800959]
#  [44678.43700736]
#  [37976.49341996]
#  [37147.16067545]
#  [50491.27402378]
#  [40366.94932913]
#  [41353.41514963]
#  [45229.90753339]
#  [53234.33653265]
#  [39400.32074453]
#  [37482.88934678]
#  [40288.54309005]
#  [32369.36967056]
#  [44040.64421989]
#  [39471.76346382]
#  [45568.25587098]
#  [54341.54067508]
#  [49556.1996099 ]
#  [44301.63073637]
#  [36568.74112435]
#  [33753.58081477]
#  [40816.24190053]
#  [45239.64370531]
#  [50029.26300426]
#  [52859.67438159]
#  [46761.51175774]
#  [40845.9539775 ]
#  [48546.61079567]
#  [42493.75558799]]
# Score: 0.2717041577530156

# %% [markdown]
# # Section 4: Validation and Testing

# %%
section_4_data = original_data.copy()

# %%
X = section_4_data.drop(["name","median_earnings"], axis=1) # use all columns except name and median_earnings
X = pd.get_dummies(X) # transform categorical columns so we can use them in linear regression
Y = section_4_data["median_earnings"]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train) # train on train set

print("training score:", model.score(x_train,y_train)) # how accurately did model capture training set relationship?
print("validation score:", model.score(x_test,y_test)) # how well can model predict new things?
# Out:
# training score: 0.769963851281587
# validation score: 0.15056033082220388

# %% [markdown]
# ## Problem 3
#
# ### Replace the 'None' values below with appropriate values to create a train-validate-test split.

# %%
problem_3_data = original_data.copy()
X = problem_3_data[["cost"]] 
Y = problem_3_data[["median_earnings"]]
x_not_test, x_test, y_not_test, y_test = train_test_split(X, Y, test_size=0.25, random_state=1) 
x_train, x_valid, y_train, y_valid = train_test_split(x_not_test, y_not_test, test_size=0.15, random_state=1)

model = LinearRegression()

# training
model.fit(x_train, y_train)

print("training score:", model.score(x_train,y_train))
print("validation score:", model.score(x_valid,y_valid))
# Out:
# training score: 0.17743199836873658
# validation score: 0.2931993427074995

# %%
print("testing score:", model.score(x_test,y_test))
# Out:
# testing score: 0.14772675950545677

# %% [markdown]
# ## Problem 4
#
# Use 'median_earnings' to predict 'median_earnings'.
#
# Remember to create a train-test split (use whatever percentage of test set you want).
#
# Print out the coefficients. Print out the model's score. Briefly explain why you got the coefficients and accuracy that you got.

# %%
problem_4_data = original_data.copy()

# %%
# split data and create model
X = problem_4_data[["median_earnings"]] 
Y = problem_4_data[["median_earnings"]]
x_not_test, x_test, y_not_test, y_test = train_test_split(X, Y, test_size=0.25, random_state=1) 
x_train, x_valid, y_train, y_valid = train_test_split(x_not_test, y_not_test, test_size=0.15, random_state=1)

model = LinearRegression()

# training
model.fit(x_train, y_train)

print("training score:", model.score(x_train,y_train))
print("validation score:", model.score(x_valid,y_valid))
# Out:
# training score: 1.0
# validation score: 1.0

# %%
# print out coefficient and score
print("testing score:", model.score(x_test,y_test))
print()
print("Coeff: ")
model.coef_[0]
# Out:
# testing score: 1.0
#
# Coeff:
# array([1.])

# %% [markdown]
# #### Briefly explain why you got the coefficients and score that you got.
#
# I got a coefficient of 1 because there is a direct (1:1) relationship between any data and itself.

# %% [markdown]
# ## Problem 5 (optional)
#
# Linear regression does well with variables that are correlated. Look up how to print out the correlation matrix of a pandas dataframe.
#
# Looking at the correlation matrix, pick at least 3 features that have a low (between -0.5 and 0.5) correlation with median_earnings and plot scatterplots of each of them against median_earnings.
# Using these scatterplot, pick one of the features and try a few transformations that might increase its correlation with median_earnings. That is, create new features (columns) and see what their correlation with median_earnings is.
#
# Create a model using one of these new features, as well as other features that are well correlated with median_earnings, as features. Print out the score.

# %%
problem_5_data = original_data.copy()
problem_5_data.head()
# Out:
#                                   name        city state  adm_rate  \
# 0             Alabama A & M University      Normal    AL    0.6538
# 1  University of Alabama at Birmingham  Birmingham    AL    0.6043
# 2  University of Alabama in Huntsville  Huntsville    AL    0.8120
# 3             Alabama State University  Montgomery    AL    0.4639
# 4            The University of Alabama  Tuscaloosa    AL    0.5359
#
#    undergrads   cost  compl_4  median_hh_inc  median_earnings
# 0        4505  20809   0.1104       49720.22            29900
# 1       11269  22232   0.3173       55735.22            40200
# 2        5829  20999   0.1848       58688.62            45600
# 3        4740  18100   0.1216       46065.20            26700
# 4       31005  27205   0.4135       57928.41            42700

# %%
# print out correlation matrix
plt.matshow(problem_5_data.corr())
cb = plt.colorbar()
plt.show()

# %%
# make scatter plots

# %%
plt.scatter(problem_5_data["adm_rate"],problem_5_data["median_earnings"])
plt.title('Admission Rate vs Median Earnings')
plt.xlabel('Admission Rate')
plt.ylabel('Median Earnings')
plt.show()

# %%
plt.scatter(problem_5_data["undergrads"],problem_5_data["median_earnings"])
plt.title('Undergrads vs Median Earnings')
plt.xlabel('Undergrads')
plt.ylabel('Median Earnings')
plt.show()

# %%
plt.scatter(problem_5_data["cost"],problem_5_data["median_earnings"])
plt.title('Cost vs Median Earnings')
plt.xlabel('Cost')
plt.ylabel('Median Earnings')
plt.show()

# %%
# create new features

# %%
def f(x,y):
    return y/(10000*x)
problem_5_data["sixth"] = problem_5_data.apply(lambda x: f(x.adm_rate, x.cost), axis=1)

# %%
plt.scatter(problem_5_data["sixth"],problem_5_data["median_earnings"])
plt.title('Sixth vs Median Earnings')
plt.xlabel('Sixth')
plt.ylabel('Median Earnings')
plt.show()

# %%
plt.matshow(problem_5_data.corr())
cb = plt.colorbar()
plt.show()

# %%
# create model

# %%
X = problem_5_data[["sixth"]] 
Y = problem_5_data[["median_earnings"]]
x_not_test, x_test, y_not_test, y_test = train_test_split(X, Y, test_size=0.2, random_state=1) 
x_train, x_valid, y_train, y_valid = train_test_split(x_not_test, y_not_test, test_size=0.2, random_state=1)

model = LinearRegression()

# training
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# get score

# %%
print("training score:", model.score(x_train,y_train))
print("validation score:", model.score(x_valid,y_valid))
# Out:
# training score: 0.1493286661329205
# validation score: 0.35076458494548146
